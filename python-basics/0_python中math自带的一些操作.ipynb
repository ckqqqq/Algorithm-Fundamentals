# %% [markdown]
# # 0_python中math自带的一些操作
#
# > 自动合成题干：文件无题面内容，需自行补充。

# %%
import math
print(math.floor(1.3),math.floor(-1.3))
print(math.ceil(1.3))
print(math.gcd(51,34))
print(math.sqrt(101))
print(math.exp(10.01))
print(math.log(1/2))
print(math.log(1/2,2))
print(math.pow(2,3))
print(math.inf)
print(math.pi,math.e)
# Out:
# 1 -2
# 2
# 17
# 10.04987562112089
# 22247.835456318233
# -0.6931471805599453
# -1.0
# 8.0
# inf
# 3.141592653589793 2.718281828459045
